# %% [markdown]
# # Data Analytics

# %% [markdown]
# <hr>

# %% [markdown]
# <h3>Data Analys: Jodel Labios</h3>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# <h3>Converting Datasets into Dataframe</h3>

# %% [markdown]
# <h3>Requirements</h3>

# %% [markdown]
# <ul>
#     <li>Name of the Dataframe</li>
#     <li>File Path</li>
# </ol>

# %%
penguins = pd.read_csv('Data_Sets\\penguins.csv')

# %% [markdown]
# <h3>Descriptive Analytics</h3>

# %%
penguins.describe()
# Out:
#             rowid  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# count  344.000000      342.000000     342.000000         342.000000
# mean   172.500000       43.921930      17.151170         200.915205
# std     99.448479        5.459584       1.974793          14.061714
# min      1.000000       32.100000      13.100000         172.000000
# 25%     86.750000       39.225000      15.600000         190.000000
# 50%    172.500000       44.450000      17.300000         197.000000
# 75%    258.250000       48.500000      18.700000         213.000000
# max    344.000000       59.600000      21.500000         231.000000
#
#        body_mass_g         year
# count   342.000000   344.000000
# mean   4201.754386  2008.029070
# std     801.954536     0.818356
# min    2700.000000  2007.000000
# 25%    3550.000000  2007.000000
# 50%    4050.000000  2008.000000
# 75%    4750.000000  2009.000000
# max    6300.000000  2009.000000

# %% [markdown]
# <h3>flip The Dataframe</h3>

# %%
penguins.describe().T
# Out:
#                    count         mean         std     min       25%      50%  \
# rowid              344.0   172.500000   99.448479     1.0    86.750   172.50
# bill_length_mm     342.0    43.921930    5.459584    32.1    39.225    44.45
# bill_depth_mm      342.0    17.151170    1.974793    13.1    15.600    17.30
# flipper_length_mm  342.0   200.915205   14.061714   172.0   190.000   197.00
# body_mass_g        342.0  4201.754386  801.954536  2700.0  3550.000  4050.00
# year               344.0  2008.029070    0.818356  2007.0  2007.000  2008.00
#
#                        75%     max
# rowid               258.25   344.0
# bill_length_mm       48.50    59.6
# bill_depth_mm        18.70    21.5
# flipper_length_mm   213.00   231.0
# body_mass_g        4750.00  6300.0
# year               2009.00  2009.0

# %% [markdown]
# <h3>Checking for Null Values</h3>

# %%
penguins.isnull()
# Out:
#      rowid  species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    False    False   False           False          False              False
# 1    False    False   False           False          False              False
# 2    False    False   False           False          False              False
# 3    False    False   False            True           True               True
# 4    False    False   False           False          False              False
# ..     ...      ...     ...             ...            ...                ...
# 339  False    False   False           False          False              False
# 340  False    False   False           False          False              False
# 341  False    False   False           False          False              False
# 342  False    False   False           False          False              False
# 343  False    False   False           False          False              False
#
#      body_mass_g    sex   year
# ...

# %% [markdown]
# <h3>Sum all the Null Values</h3>

# %%
penguins.isnull().sum()
# Out:
# rowid                 0
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# dtype: int64

# %% [markdown]
# <h3>Filtering a column</h3>

# %%
penguins['species']
# Out:
# 0         Adelie
# 1         Adelie
# 2         Adelie
# 3         Adelie
# 4         Adelie
#          ...
# 339    Chinstrap
# 340    Chinstrap
# 341    Chinstrap
# 342    Chinstrap
# 343    Chinstrap
# Name: species, Length: 344, dtype: object

# %% [markdown]
# <h3>Checking Value Counts</h3>

# %%
penguins['species'].value_counts()
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %% [markdown]
# <h3>Filtering  cell in column</h3>

# %%
penguins[penguins['species'] == 'Chinstrap']
# Out:
#      rowid    species island  bill_length_mm  bill_depth_mm  \
# 276    277  Chinstrap  Dream            46.5           17.9
# 277    278  Chinstrap  Dream            50.0           19.5
# 278    279  Chinstrap  Dream            51.3           19.2
# 279    280  Chinstrap  Dream            45.4           18.7
# 280    281  Chinstrap  Dream            52.7           19.8
# ..     ...        ...    ...             ...            ...
# 339    340  Chinstrap  Dream            55.8           19.8
# 340    341  Chinstrap  Dream            43.5           18.1
# 341    342  Chinstrap  Dream            49.6           18.2
# 342    343  Chinstrap  Dream            50.8           19.0
# 343    344  Chinstrap  Dream            50.2           18.7
#
#      flipper_length_mm  body_mass_g     sex  year
# 276              192.0       3500.0  female  2007
# 277              196.0       3900.0    male  2007
# 278              193.0       3650.0    male  2007
# ...

# %%
penguins[penguins['species'] != 'Chinstrap']
# Out:
#      rowid species     island  bill_length_mm  bill_depth_mm  \
# 0        1  Adelie  Torgersen            39.1           18.7
# 1        2  Adelie  Torgersen            39.5           17.4
# 2        3  Adelie  Torgersen            40.3           18.0
# 3        4  Adelie  Torgersen             NaN            NaN
# 4        5  Adelie  Torgersen            36.7           19.3
# ..     ...     ...        ...             ...            ...
# 271    272  Gentoo     Biscoe             NaN            NaN
# 272    273  Gentoo     Biscoe            46.8           14.3
# 273    274  Gentoo     Biscoe            50.4           15.7
# 274    275  Gentoo     Biscoe            45.2           14.8
# 275    276  Gentoo     Biscoe            49.9           16.1
#
#      flipper_length_mm  body_mass_g     sex  year
# 0                181.0       3750.0    male  2007
# 1                186.0       3800.0  female  2007
# 2                195.0       3250.0  female  2007
# ...

# %%
penguins[penguins['island'] == 'Torgersen']
# Out:
#      rowid species     island  bill_length_mm  bill_depth_mm  \
# 0        1  Adelie  Torgersen            39.1           18.7
# 1        2  Adelie  Torgersen            39.5           17.4
# 2        3  Adelie  Torgersen            40.3           18.0
# 3        4  Adelie  Torgersen             NaN            NaN
# 4        5  Adelie  Torgersen            36.7           19.3
# 5        6  Adelie  Torgersen            39.3           20.6
# 6        7  Adelie  Torgersen            38.9           17.8
# 7        8  Adelie  Torgersen            39.2           19.6
# 8        9  Adelie  Torgersen            34.1           18.1
# 9       10  Adelie  Torgersen            42.0           20.2
# 10      11  Adelie  Torgersen            37.8           17.1
# 11      12  Adelie  Torgersen            37.8           17.3
# 12      13  Adelie  Torgersen            41.1           17.6
# 13      14  Adelie  Torgersen            38.6           21.2
# ...

# %% [markdown]
# <h3>Create another Dataframe based on the original Dataframe</h3>

# %%
new_data = penguins[penguins['species'] == 'Chinstrap']

# %%
new_data
# Out:
#      rowid    species island  bill_length_mm  bill_depth_mm  \
# 276    277  Chinstrap  Dream            46.5           17.9
# 277    278  Chinstrap  Dream            50.0           19.5
# 278    279  Chinstrap  Dream            51.3           19.2
# 279    280  Chinstrap  Dream            45.4           18.7
# 280    281  Chinstrap  Dream            52.7           19.8
# ..     ...        ...    ...             ...            ...
# 339    340  Chinstrap  Dream            55.8           19.8
# 340    341  Chinstrap  Dream            43.5           18.1
# 341    342  Chinstrap  Dream            49.6           18.2
# 342    343  Chinstrap  Dream            50.8           19.0
# 343    344  Chinstrap  Dream            50.2           18.7
#
#      flipper_length_mm  body_mass_g     sex  year
# 276              192.0       3500.0  female  2007
# 277              196.0       3900.0    male  2007
# 278              193.0       3650.0    male  2007
# ...

# %% [markdown]
# <h3>Cleaning the Dataframe</h3>

# %%
penguins['bill_length_mm'].mean()
# Out:
# np.float64(43.9219298245614)

# %%
penguins['bill_length_mm'] = penguins['bill_length_mm'].fillna(penguins['bill_length_mm'].mean())

# %%
penguins.isnull().sum()
# Out:
# rowid                 0
# species               0
# island                0
# bill_length_mm        0
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# dtype: int64

# %%
penguins['bill_depth_mm'].mean()
# Out:
# np.float64(17.151169590643274)

# %%
penguins['bill_depth_mm'] = penguins['bill_depth_mm'].fillna(penguins['bill_depth_mm'].mean())

# %%
penguins.isnull().sum()
# Out:
# rowid                 0
# species               0
# island                0
# bill_length_mm        0
# bill_depth_mm         0
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# dtype: int64

# %%
penguins['flipper_length_mm'].mean()
# Out:
# np.float64(200.91520467836258)

# %%
penguins['flipper_length_mm'] = penguins['flipper_length_mm'].fillna(penguins['flipper_length_mm'].mean())

# %%
penguins.isnull().sum()
# Out:
# rowid                 0
# species               0
# island                0
# bill_length_mm        0
# bill_depth_mm         0
# flipper_length_mm     0
# body_mass_g           2
# sex                  11
# year                  0
# dtype: int64

# %%
penguins['body_mass_g'].mean()
# Out:
# np.float64(4201.754385964912)

# %%
penguins['body_mass_g'] = penguins['body_mass_g'].fillna(penguins['body_mass_g'].mean())

# %%
penguins.isnull().sum()
# Out:
# rowid                 0
# species               0
# island                0
# bill_length_mm        0
# bill_depth_mm         0
# flipper_length_mm     0
# body_mass_g           0
# sex                  11
# year                  0
# dtype: int64

# %%
penguins['sex'].mode()
# Out:
# 0    male
# Name: sex, dtype: object

# %%
penguins['sex'] = penguins['sex'].fillna(0)

# %%
penguins.isnull().sum()
# Out:
# rowid                0
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# year                 0
# dtype: int64

# %% [markdown]
# <h3>Add column in the Dataframe</h3>

# %%
penguins['mass_kg'] = np.round(penguins['body_mass_g'] / 1000, 1)

# %%
penguins
# Out:
#      rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0        1     Adelie  Torgersen        39.10000       18.70000
# 1        2     Adelie  Torgersen        39.50000       17.40000
# 2        3     Adelie  Torgersen        40.30000       18.00000
# 3        4     Adelie  Torgersen        43.92193       17.15117
# 4        5     Adelie  Torgersen        36.70000       19.30000
# ..     ...        ...        ...             ...            ...
# 339    340  Chinstrap      Dream        55.80000       19.80000
# 340    341  Chinstrap      Dream        43.50000       18.10000
# 341    342  Chinstrap      Dream        49.60000       18.20000
# 342    343  Chinstrap      Dream        50.80000       19.00000
# 343    344  Chinstrap      Dream        50.20000       18.70000
#
#      flipper_length_mm  body_mass_g     sex  year  mass_kg
# 0           181.000000  3750.000000    male  2007      3.8
# 1           186.000000  3800.000000  female  2007      3.8
# ...

# %% [markdown]
# <h3>Exploratory Data Analytics (EDA)</h3>

# %% [markdown]
# <hr>

# %% [markdown]
# <h4>Question 1</h4>
# <h5>Which species has the longest flipper length?</h5>

# %%
penguins['flipper_length_mm'].max()
# Out:
# np.float64(231.0)

# %%
penguins[penguins['flipper_length_mm'] == 231.0]
# Out:
#      rowid species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 215    216  Gentoo  Biscoe            54.3           15.7              231.0
#
#      body_mass_g   sex  year  mass_kg
# 215       5650.0  male  2008      5.6

# %% [markdown]
# <h4>Insigth No.1</h4>
# <h5>Species of Gentoo has the longest flipper length</h5>
# <hr>

# %% [markdown]
# <br>
# <h4>Question 2</h4>
# <h5>Which species has the deepest bill depth?</h5>

# %%
penguins['bill_depth_mm'].max()
# Out:
# np.float64(21.5)

# %%
penguins[penguins['bill_depth_mm'] == 21.5]
# Out:
#     rowid species     island  bill_length_mm  bill_depth_mm  \
# 19     20  Adelie  Torgersen            46.0           21.5
#
#     flipper_length_mm  body_mass_g   sex  year  mass_kg
# 19              194.0       4200.0  male  2007      4.2

# %% [markdown]
# <h4>Insigth No.2</h4>
# <h5>Species  of Adelie  has the deepest bill depth</h5>
# <hr>

# %% [markdown]
# <br>
# <h4>Question 3</h4>

# %% [markdown]
# <h5>Which species has the longest bill length</h5>

# %%
penguins['bill_length_mm'].max()
# Out:
# np.float64(59.6)

# %%
penguins[penguins['bill_length_mm'] == 59.6]
# Out:
#      rowid species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 185    186  Gentoo  Biscoe            59.6           17.0              230.0
#
#      body_mass_g   sex  year  mass_kg
# 185       6050.0  male  2007      6.0

# %% [markdown]
# <h4>Insight No.3</h4>
# <h5>Species of gentoo has the longest bill length</h5>
# <hr>

# %% [markdown]
# <br>
# <h4>Question 4</h4>
# <h5>Which species has the heviest body mass?</h5>

# %%
penguins['mass_kg'].max()
# Out:
# np.float64(6.3)

# %%
penguins[penguins['mass_kg'] == 6.3]
# Out:
#      rowid species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 169    170  Gentoo  Biscoe            49.2           15.2              221.0
#
#      body_mass_g   sex  year  mass_kg
# 169       6300.0  male  2007      6.3

# %% [markdown]
# <h4>Insigth No.4</h4>
# <h5>Species of gentoo has the heviest body mass</h5>
# <hr>

# %% [markdown]
# <br>
# <h4>Question 5</h4>
# <h5>Which island has more female penguins</h5>

# %%
Torgersen = penguins[penguins['island'] == 'Torgersen']

# %%
Torgersen['sex'].value_counts()
# Out:
# sex
# female    24
# male      23
# 0          5
# Name: count, dtype: int64

# %%
Dream = penguins[penguins['island'] == 'Dream']

# %%
Dream['sex'].value_counts()
# Out:
# sex
# male      62
# female    61
# 0          1
# Name: count, dtype: int64

# %%
Biscoe = penguins[penguins['island'] == 'Biscoe']

# %%
Biscoe['sex'].value_counts()
# Out:
# sex
# male      83
# female    80
# 0          5
# Name: count, dtype: int64

# %% [markdown]
# <h4>Insight No.5</h4>
# <h5>Biscoe island has more female penguins than other island </h5>
# <hr>

# %% [markdown]
# <br>
# <h4>Question 6</h4>
# <h5>Which island has more male penguins</h5>

# %%
Torgersen2 = penguins[penguins['island'] == 'Torgersen']

# %%
Torgersen2['sex'].value_counts()
# Out:
# sex
# female    24
# male      23
# 0          5
# Name: count, dtype: int64

# %%
Biscoe2 = penguins[penguins['island'] == 'Biscoe']

# %%
Biscoe2['sex'].value_counts()
# Out:
# sex
# male      83
# female    80
# 0          5
# Name: count, dtype: int64

# %%
Dream2 = penguins[penguins['island'] == 'Dream']

# %%
Dream2['sex'].value_counts()
# Out:
# sex
# male      62
# female    61
# 0          1
# Name: count, dtype: int64

# %% [markdown]
# <h4>Insight No.6</h4>
# <h5>Dream island has more male penguins than other island</h5>
# <hr>

# %% [markdown]
# <br>
# <h4>Question 7</h4>
# <h5>Which species of penguins has most numerous?</h5>

# %%
penguins['species'].value_counts()
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %% [markdown]
# <h4>Insight No.7</h4>
# <h5>Species of Adelie has the most numerous species of penguins</h5>
