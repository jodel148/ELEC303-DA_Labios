# %% [markdown]
# <h1>Activity 4: Dengue Record Data Analytics</h1>
# <hr>
# <br>

# %% [markdown]
# <h2>Data Analyst: Jodel Labios</h2>
# <br>

# %%
import pandas as pd
import numpy as np
import warnings
import matplotlib.pyplot as plt 
warnings.filterwarnings('ignore')

# %% [markdown]
# <br>

# %% [markdown]
# <h3>Converting Datasets to Data frame</h3>

# %% [markdown]
# <ul>
#     <li>Data frame name</li>
#     <li>File path</li>
# </ul>
# <br>

# %%
Dengue_df = pd.read_csv('Data_Sets\\dengue.csv')

# %%
Dengue_df
# Out:
#           Month  Year    Region  Dengue_Cases  Dengue_Deaths
# 0       January  2016  Region I           705              1
# 1      February  2016  Region I           374              0
# 2         March  2016  Region I           276              0
# 3         April  2016  Region I           240              2
# 4           May  2016  Region I           243              1
# ...         ...   ...       ...           ...            ...
# 1015     August  2020     BARMM            91              0
# 1016  September  2020     BARMM            16              8
# 1017    October  2020     BARMM            13              9
# 1018   November  2020     BARMM            15              1
# 1019   December  2020     BARMM            23              0
#
# [1020 rows x 5 columns]

# %% [markdown]
# <hr>
# <h1>Exploratory Analysis</h1>
# <br>

# %% [markdown]
# <h2>Monthly dengue case from 2016 to 2020?</h2>

# %%
month_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
Dengue_df['Month'] = pd.Categorical(Dengue_df['Month'], categories =month_order, ordered = True )
monthly_cases = Dengue_df.groupby(['Month', 'Year'])['Dengue_Cases'].sum()

# %%
monthly_cases.unstack().plot(kind='line')
plt.gcf().set_size_inches(12,8)
plt.grid(True)
plt.xticks(range(0,12), month_order)
plt.show()

# %% [markdown]
# <h3>Insigth No. 1: Based on the Data shown above. From month of january to march, june to august and october to december cases of dengue has always increased in this month yearly. But the highest cases of dengue is in the month of july. In 2020, the Philippines recorded a substantial decrease in the number of dengue cases, with a reduction in notified cases of about 70–90% during the rainy season . Apart from existing control and prevention measures implemented in the country, such as the establishment of dengue centres of excellence in tertiary hospitals and the creation of dengue fast lanes.The decrease in the number of cases during the COVID-19 pandemic may be largely due to the reduced mobility of the population. </h3>

# %% [markdown]
# <h3>Insigth No. 2: Month of june to december is a rainy season which Dengue cases are most prevalent in the Philippines when there is more rainfall, which creates more breeding sites for mosquitoes, and higher temperatures, which accelerate mosquito development.</h3>
# <hr>
# <br>

# %% [markdown]
# <h2>Dengue cases from all regions of Philippines</h2>

# %%
 Dengue_df.groupby('Region')['Dengue_Cases'].sum().plot(kind='bar', figsize=(15, 5))
# Out:
# <Axes: xlabel='Region'>

# %% [markdown]
# <br>
# <h2>Death Cases from dengue in all regions of Philippines</h2>

# %%
 Dengue_df.groupby('Region')['Dengue_Deaths'].sum().plot(kind='bar', figsize=(15, 5))
# Out:
# <Axes: xlabel='Region'>

# %% [markdown]
# <h3>Insigth No. 3: Region of NCR, Region III, Region IV-A, Region VI, Region VII, Region X, Region XII. This region has the most cases of dengue.</h3>

# %% [markdown]
# <h3>Insigth No. 4: Regions with the most dengue cases, such as NCR, Region III, Region IV-A, Region VI, Region VII, Region X, and Region XII, experience high cases of dengue due to factors like dense populations, urbanization, climate, and environmental conditions that favor Aedes mosquitoes.</h3>

# %% [markdown]
# <h3>Insigth No. 5: Region of NCR, Region VI and Region VII has the most death cases in dengue</h3>

# %% [markdown]
# <h3>Insigth No. 6: Regions with the most dengue deaths likely have high case numbers due to a combination of large populations, increased mosquito-breeding sites, and factors like urbanization, environmental conditions, and potentially late-stage medical intervention</h3>
# <hr>
# <br>

# %% [markdown]
# <h1>Region 4A</h1>

# %%
Region_4A =  Dengue_df[Dengue_df['Region'] == 'Region IV-A']
month_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
Dengue_df['Month'] = pd.Categorical(Dengue_df['Month'], categories =month_order, ordered = True )
monthly_cases = Region_4A.groupby(['Month', 'Year'])['Dengue_Cases'].sum()

# %%
monthly_cases.unstack().plot(kind='line', title = 'Dengue Cases in Region IV-A')
plt.gcf().set_size_inches(12,8)
plt.grid(True)
plt.xticks(range(0,12), month_order)
plt.show()

# %% [markdown]
# <h3>Insigth No. 7: In region 4A month of january to march, june to july and october to december has the most case of dengue. But in the year 2020 dengue cases has decreased from april to december  </h3>

# %% [markdown]
# <h3>Insigth No. 8: Region 4A has the most cases of dengue due to its large population, high population density, and a combination of urban and rural areas that facilitate mosquito breeding. Region 4A is one of the most populous regions in the Philippines, with a large population density. The higher the number of people, the greater the potential for transmission.</h3>
# <hr>
# <br>

# %% [markdown]
# <h1>NCR</h1>

# %%
NCR =  Dengue_df[Dengue_df['Region'] == 'NCR']
month_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
Dengue_df['Month'] = pd.Categorical(Dengue_df['Month'], categories =month_order, ordered = True )
monthly_cases = NCR.groupby(['Month', 'Year'])['Dengue_Deaths'].sum()

# %%
monthly_cases.unstack().plot(kind='line', title = 'Death Cases In Dengue In NCR')
plt.gcf().set_size_inches(12,8)
plt.grid(True)
plt.xticks(range(0,12), month_order)
plt.show()

# %% [markdown]
# <h3>Insigth No. 9:  Based on the data shown above, In 2020 from month of october to december has the highest death case of dengue</h3>

# %% [markdown]
# <h3>Insigth No. 10:  In 2020, the National Capital Region (NCR) likely had the most dengue deaths due to a combination of high population density, ongoing urbanization challenges, and limitations related to the COVID-19 pandemic.</h3>

# %%
Dengue_df.describe()
